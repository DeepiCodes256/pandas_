# %%
import numpy as np 
import pandas as pd 
data = pd.read_csv("assignment_for_project.csv")
data
def show_assignments():
    data.sort_values('Dure Date')
# Out:
#      Subject Assignment Name    Due Date     Status Priority
# 0        Eng             ABC  27-05-2026    Pending     High
# 1       Math         Deepika  29-05-2026  Completed   Medium
# 2       Chem          Deepak  21-05-2026    Pending      Low
# 3       Math           Deepa  17-05-2026  Completed     High
# 4        Bio           Dippa  05-06-2026  Completed     High
# 5  Aerospace           Mausi  01-06-2026  Completed      Low
# 6     Kungfu            Pika  15-04-2025    Pending      Low
# 7      Huiha             Chu  01-06-2007  Completed      Low
